# %% [markdown]
# <a href="https://colab.research.google.com/github/Kritika-B05/Machine-Learning/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
np.random.seed(42)

# %%
ad_spend = np.random.uniform(5, 50, 100)

# %%
noise = np.random.normal(0, 5, 100)
data_sales = 3.5 * ad_spend + noise

# %%
data = pd.DataFrame({
    'Advertising_Spend': ad_spend,
    'Sales': data_sales
})

# %%
data.to_csv('business_linear_regression_dataset.csv', index=False)
print("Dataset saved as 'business_linear_regression_dataset.csv'")
# Out:
# Dataset saved as 'business_linear_regression_dataset.csv'

# %%
df = pd.read_csv('business_linear_regression_dataset.csv')
df
# Out:
#     Advertising_Spend       Sales
# 0           21.854305   76.925304
# 1           47.782144  165.742467
# 2           37.939727  133.247850
# 3           31.939632  101.850867
# 4           12.020839   40.974576
# ..                ...         ...
# 95          27.220802   91.193755
# 96          28.522977   99.444912
# 97          24.239346   86.543470
# 98           6.143861   22.886966
# 99           9.855114   38.628816
#
# [100 rows x 2 columns]

# %%
df.head()
# Out:
#    Advertising_Spend       Sales
# 0          21.854305   76.925304
# 1          47.782144  165.742467
# 2          37.939727  133.247850
# 3          31.939632  101.850867
# 4          12.020839   40.974576

# %%
df.shape
# Out:
# (100, 2)

# %%
df.isnull().sum()
# Out:
# Advertising_Spend    0
# Sales                0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Advertising_Spend, Sales]
# Index: []

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Advertising_Spend, Sales]
# Index: []

# %%
df.describe()
# Out:
#        Advertising_Spend       Sales
# count         100.000000  100.000000
# mean           26.158133   91.548065
# std            13.387023   46.390746
# min             5.248495   20.026177
# 25%            13.694034   49.860209
# 50%            25.886410   88.989364
# 75%            37.859140  134.158092
# max            49.409912  176.843807

# %%
plt.scatter(df['Advertising_Spend'],df['Sales'])
plt.xlabel('Advertising_Spend')
plt.ylabel('Sales(in rupees)')
# Out:
# Text(0, 0.5, 'Sales(in rupees)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      76.925304
# 1     165.742467
# 2     133.247850
# 3     101.850867
# 4      40.974576
#          ...
# 95     91.193755
# 96     99.444912
# 97     86.543470
# 98     22.886966
# 99     38.628816
# Name: Sales, Length: 100, dtype: float64

# %%
X
# Out:
#     Advertising_Spend
# 0           21.854305
# 1           47.782144
# 2           37.939727
# 3           31.939632
# 4           12.020839
# ..                ...
# 95          27.220802
# 96          28.522977
# 97          24.239346
# 98           6.143861
# 99           9.855114
#
# [100 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
y_pred
# Out:
# array([ 28.81838398, 113.11916567,  32.68239251,  89.64532998,
#         66.11681001,  75.74339238, 132.40485663,  98.65898922,
#        110.77444813,  51.87471785,  35.68861515, 136.86657177,
#        138.49146287,  47.14598627,  77.01076762,  40.58599744,
#        111.74205844,  26.16719225,  61.01939783,  36.92489704])

# %%
y_test
# Out:
# 83     30.793208
# 30    122.619244
# 56     26.126051
# 24     82.254169
# 16     61.907888
# 23     74.029055
# 2     133.247850
# 27     94.480538
# 28    109.998866
# 13     53.509747
# 99     38.628816
# 92    136.096705
# 76    135.574956
# 14     46.622820
# 0      76.925304
# 21     40.775559
# 3     101.850867
# 29     26.836194
# 61     58.627165
# 79     32.177620
# Name: Sales, dtype: float64

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9865448016304293

# %%
plt.scatter(df['Advertising_Spend'],df['Sales'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('Advertising_Spend')
plt.ylabel('Sales(in rupees)')
# Out:
# Text(0, 0.5, 'Sales(in rupees)')

# %%
m = lr.coef_

# %%
m
# Out:
# array([3.44374483])

# %%
b = lr.intercept_

# %%
b
# Out:
# 1.7501164938723406

# %%
m * 8.58 + b
# Out:
# array([31.29744716])

# %%
m * 9.5 + b
# Out:
# array([34.46569241])

# %%
m * 6.94 + b
# Out:
# array([25.64970564])
